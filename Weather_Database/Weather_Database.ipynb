# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})

    # If an error is experienced, skip the city.
    except Exception as e:
        print(f"Error = {e}")
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | muros
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | cabedelo
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | davila
# Processing Record 8 of Set 1 | myitkyina
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | san felipe
# Processing Record 11 of Set 1 | ust-kamchatsk
# Error = 'sys'
# City not found. Skipping...
# Processing Record 12 of Set 1 | attawapiskat
# Error = 'sys'
# City not found. Skipping...
# Processing Record 13 of Set 1 | port-gentil
# Processing Record 14 of Set 1 | huanren
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | wilmington island
# Processing Record 18 of Set 1 | hambantota
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | hamilton
# Processing Record 21 of Set 1 | ulaanbaatar
# Processing Record 22 of Set 1 | brus laguna
# Processing Record 23 of Set 1 | victoria
# Processing Record 24 of Set 1 | casper
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | yarmouth
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | itoman
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | illoqqortoormiut
# Error = 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 1 | kloulklubed
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | ambon
# Processing Record 37 of Set 1 | kilindoni
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | oksfjord
# Processing Record 41 of Set 1 | entebbe
# Processing Record 42 of Set 1 | lolua
# Error = 'sys'
# City not found. Skipping...
# Processing Record 43 of Set 1 | port blair
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | carutapera
# Processing Record 46 of Set 1 | linares
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | djougou
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | yakeshi
# Processing Record 5 of Set 2 | umuarama
# Processing Record 6 of Set 2 | hay river
# Processing Record 7 of Set 2 | astipalaia
# Error = 'sys'
# City not found. Skipping...
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | tungor
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | hastings
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | ucluelet
# Processing Record 17 of Set 2 | zapolyarnyy
# Processing Record 18 of Set 2 | taolanaro
# Error = 'sys'
# City not found. Skipping...
# Processing Record 19 of Set 2 | klaksvik
# Processing Record 20 of Set 2 | lavrentiya
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | copperas cove
# Processing Record 24 of Set 2 | kysyl-syr
# Processing Record 25 of Set 2 | hobyo
# Processing Record 26 of Set 2 | vila do maio
# Processing Record 27 of Set 2 | tocopilla
# Processing Record 28 of Set 2 | safwah
# Error = 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 2 | mirabad
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | kandrian
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | port-cartier
# Processing Record 34 of Set 2 | mount gambier
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | pinyug
# Processing Record 38 of Set 2 | saint-georges
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | ushuaia
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | katherine
# Processing Record 43 of Set 2 | campo maior
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | bonavista
# Processing Record 48 of Set 2 | sovetskiy
# Processing Record 49 of Set 2 | rikitea
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | amderma
# Error = 'sys'
# City not found. Skipping...
# Processing Record 2 of Set 3 | yangambi
# Processing Record 3 of Set 3 | alice springs
# Processing Record 4 of Set 3 | miyako
# Processing Record 5 of Set 3 | mathbaria
# Processing Record 6 of Set 3 | grand centre
# Error = 'sys'
# City not found. Skipping...
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | kruisfontein
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | goundam
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | kalmunai
# Processing Record 15 of Set 3 | ahuimanu
# Processing Record 16 of Set 3 | merauke
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | doha
# Processing Record 19 of Set 3 | belaya gora
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | datong
# Processing Record 22 of Set 3 | yerbogachen
# Processing Record 23 of Set 3 | stavern
# Processing Record 24 of Set 3 | grand river south east
# Error = 'sys'
# City not found. Skipping...
# Processing Record 25 of Set 3 | guider
# Processing Record 26 of Set 3 | lagoa
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | punta arenas
# Processing Record 29 of Set 3 | helong
# Processing Record 30 of Set 3 | sambava
# Processing Record 31 of Set 3 | ulladulla
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | srednekolymsk
# Processing Record 34 of Set 3 | vanimo
# Processing Record 35 of Set 3 | saint-pierre
# Processing Record 36 of Set 3 | sajanan
# Processing Record 37 of Set 3 | bambanglipuro
# Processing Record 38 of Set 3 | san pedro
# Processing Record 39 of Set 3 | itarema
# Processing Record 40 of Set 3 | basoko
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | yankton
# Processing Record 43 of Set 3 | lamu
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | urusha
# Processing Record 46 of Set 3 | lac-megantic
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | codrington
# Processing Record 49 of Set 3 | talnakh
# Processing Record 50 of Set 3 | ermelo
# Processing Record 1 of Set 4 | north bend
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | price
# Processing Record 4 of Set 4 | kenai
# Processing Record 5 of Set 4 | gasa
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | mokhsogollokh
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | khani
# Processing Record 10 of Set 4 | tual
# Processing Record 11 of Set 4 | awash
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | quatre cocos
# Processing Record 14 of Set 4 | nizhneyansk
# Error = 'sys'
# City not found. Skipping...
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | sitka
# Processing Record 17 of Set 4 | erken-shakhar
# Error = 'sys'
# City not found. Skipping...
# Processing Record 18 of Set 4 | smolensk
# Processing Record 19 of Set 4 | saldanha
# Processing Record 20 of Set 4 | kongolo
# Processing Record 21 of Set 4 | georgetown
# Processing Record 22 of Set 4 | lasa
# Processing Record 23 of Set 4 | gigmoto
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | komsomolskiy
# Processing Record 27 of Set 4 | geraldton
# Processing Record 28 of Set 4 | altamont
# Processing Record 29 of Set 4 | ahipara
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | auki
# Processing Record 32 of Set 4 | meadow lake
# Processing Record 33 of Set 4 | chabahar
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | port hedland
# Processing Record 36 of Set 4 | salalah
# Processing Record 37 of Set 4 | hofn
# Processing Record 38 of Set 4 | zhezkazgan
# Processing Record 39 of Set 4 | berlevag
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | puerto ayacucho
# Processing Record 42 of Set 4 | owosso
# Processing Record 43 of Set 4 | constitucion
# Processing Record 44 of Set 4 | sioux lookout
# Processing Record 45 of Set 4 | nizwa
# Processing Record 46 of Set 4 | kuche
# Error = 'sys'
# City not found. Skipping...
# Processing Record 47 of Set 4 | evensk
# Processing Record 48 of Set 4 | bambous virieux
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | kishtwar
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | paamiut
# Processing Record 3 of Set 5 | roald
# Processing Record 4 of Set 5 | gat
# Processing Record 5 of Set 5 | moron
# Processing Record 6 of Set 5 | skibbereen
# Processing Record 7 of Set 5 | louisbourg
# Error = 'sys'
# City not found. Skipping...
# Processing Record 8 of Set 5 | lerwick
# Processing Record 9 of Set 5 | barentsburg
# Error = 'sys'
# City not found. Skipping...
# Processing Record 10 of Set 5 | muskogee
# Processing Record 11 of Set 5 | vaitupu
# Error = 'sys'
# City not found. Skipping...
# Processing Record 12 of Set 5 | port elizabeth
# Processing Record 13 of Set 5 | dzilam gonzalez
# Processing Record 14 of Set 5 | verkhnevilyuysk
# Processing Record 15 of Set 5 | samusu
# Error = 'sys'
# City not found. Skipping...
# Processing Record 16 of Set 5 | peniche
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | chicama
# Processing Record 19 of Set 5 | bonfim
# Processing Record 20 of Set 5 | haines junction
# Processing Record 21 of Set 5 | fayaoue
# Processing Record 22 of Set 5 | ende
# Processing Record 23 of Set 5 | eureka
# Processing Record 24 of Set 5 | svetlaya
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | bani
# Processing Record 27 of Set 5 | berdigestyakh
# Processing Record 28 of Set 5 | cowansville
# Processing Record 29 of Set 5 | yeppoon
# Processing Record 30 of Set 5 | altay
# Processing Record 31 of Set 5 | mitsamiouli
# Processing Record 32 of Set 5 | coalinga
# Processing Record 33 of Set 5 | dakar
# Processing Record 34 of Set 5 | kungsbacka
# Processing Record 35 of Set 5 | quatis
# Processing Record 36 of Set 5 | ayan
# Processing Record 37 of Set 5 | marshall
# Processing Record 38 of Set 5 | mys shmidta
# Error = 'sys'
# City not found. Skipping...
# Processing Record 39 of Set 5 | mortka
# Processing Record 40 of Set 5 | altamira
# Processing Record 41 of Set 5 | noyabrsk
# Processing Record 42 of Set 5 | dikson
# Processing Record 43 of Set 5 | andenes
# Processing Record 44 of Set 5 | comrat
# Processing Record 45 of Set 5 | tessalit
# Processing Record 46 of Set 5 | sosnovo-ozerskoye
# Processing Record 47 of Set 5 | bethel
# Processing Record 48 of Set 5 | stromness
# Processing Record 49 of Set 5 | souillac
# Processing Record 50 of Set 5 | kvarkeno
# Processing Record 1 of Set 6 | umzimvubu
# Error = 'sys'
# City not found. Skipping...
# Processing Record 2 of Set 6 | lang son
# Processing Record 3 of Set 6 | arlit
# Processing Record 4 of Set 6 | aksha
# Processing Record 5 of Set 6 | stanislav
# Processing Record 6 of Set 6 | tasiilaq
# Processing Record 7 of Set 6 | hasaki
# Processing Record 8 of Set 6 | jefferson city
# Processing Record 9 of Set 6 | whitehorse
# Processing Record 10 of Set 6 | macheng
# Processing Record 11 of Set 6 | gold coast
# Processing Record 12 of Set 6 | nueva gerona
# Processing Record 13 of Set 6 | amapa
# Processing Record 14 of Set 6 | catuday
# Processing Record 15 of Set 6 | rincon
# Processing Record 16 of Set 6 | langenburg
# Processing Record 17 of Set 6 | jinxiang
# Processing Record 18 of Set 6 | kaliua
# Processing Record 19 of Set 6 | nouadhibou
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | poum
# Processing Record 23 of Set 6 | plettenberg bay
# Processing Record 24 of Set 6 | tchollire
# Processing Record 25 of Set 6 | marsh harbour
# Processing Record 26 of Set 6 | kailua
# Processing Record 27 of Set 6 | waw
# Processing Record 28 of Set 6 | keetmanshoop
# Processing Record 29 of Set 6 | progreso
# Processing Record 30 of Set 6 | alekseyevka
# Processing Record 31 of Set 6 | tapaua
# Error = 'sys'
# City not found. Skipping...
# Processing Record 32 of Set 6 | tartagal
# Processing Record 33 of Set 6 | okha
# Processing Record 34 of Set 6 | iqaluit
# Processing Record 35 of Set 6 | kenitra
# Processing Record 36 of Set 6 | clyde river
# Processing Record 37 of Set 6 | ostrovnoy
# Processing Record 38 of Set 6 | yaita
# Processing Record 39 of Set 6 | orange cove
# Processing Record 40 of Set 6 | praia
# Processing Record 41 of Set 6 | lincoln
# Processing Record 42 of Set 6 | olafsvik
# Processing Record 43 of Set 6 | tornio
# Processing Record 44 of Set 6 | viligili
# Error = 'sys'
# City not found. Skipping...
# Processing Record 45 of Set 6 | chastyye
# Processing Record 46 of Set 6 | riyadh
# Processing Record 47 of Set 6 | muhoroni
# Processing Record 48 of Set 6 | dali
# Processing Record 49 of Set 6 | kajaani
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | minna
# Processing Record 2 of Set 7 | marcona
# Error = 'sys'
# City not found. Skipping...
# Processing Record 3 of Set 7 | honningsvag
# Processing Record 4 of Set 7 | vrede
# Processing Record 5 of Set 7 | lodeynoye pole
# Processing Record 6 of Set 7 | socorro
# Processing Record 7 of Set 7 | fairbanks
# Processing Record 8 of Set 7 | itaituba
# Processing Record 9 of Set 7 | suao
# Error = 'sys'
# City not found. Skipping...
# Processing Record 10 of Set 7 | gbadolite
# Processing Record 11 of Set 7 | north platte
# Processing Record 12 of Set 7 | nelson bay
# Processing Record 13 of Set 7 | jaque
# Processing Record 14 of Set 7 | artyk
# Error = 'sys'
# City not found. Skipping...
# Processing Record 15 of Set 7 | maltahohe
# Processing Record 16 of Set 7 | beloha
# Processing Record 17 of Set 7 | kodinsk
# Processing Record 18 of Set 7 | carauari
# Processing Record 19 of Set 7 | nardaran
# Processing Record 20 of Set 7 | vao
# Processing Record 21 of Set 7 | egvekinot
# Processing Record 22 of Set 7 | kaset sombun
# Processing Record 23 of Set 7 | chokurdakh
# Processing Record 24 of Set 7 | thinadhoo
# Processing Record 25 of Set 7 | krasnoselkup
# Processing Record 26 of Set 7 | concordia
# Processing Record 27 of Set 7 | pisco
# Processing Record 28 of Set 7 | mayo
# Processing Record 29 of Set 7 | northam
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | adrar
# Processing Record 32 of Set 7 | noumea
# Processing Record 33 of Set 7 | kishi
# Processing Record 34 of Set 7 | saint-augustin
# Processing Record 35 of Set 7 | tsihombe
# Error = 'sys'
# City not found. Skipping...
# Processing Record 36 of Set 7 | christchurch
# Processing Record 37 of Set 7 | hindupur
# Processing Record 38 of Set 7 | freeport
# Processing Record 39 of Set 7 | borogontsy
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | vostok
# Processing Record 42 of Set 7 | amuntai
# Processing Record 43 of Set 7 | paz de ariporo
# Error = 'sys'
# City not found. Skipping...
# Processing Record 44 of Set 7 | mosquera
# Processing Record 45 of Set 7 | gagra
# Processing Record 46 of Set 7 | wittmund
# Processing Record 47 of Set 7 | sentyabrskiy
# Error = 'sys'
# City not found. Skipping...
# Processing Record 48 of Set 7 | yaan
# Processing Record 49 of Set 7 | mangan
# Processing Record 50 of Set 7 | cedar city
# Processing Record 1 of Set 8 | comodoro rivadavia
# Processing Record 2 of Set 8 | yanan
# Error = 'sys'
# City not found. Skipping...
# Processing Record 3 of Set 8 | gari
# Processing Record 4 of Set 8 | belushya guba
# Error = 'sys'
# City not found. Skipping...
# Processing Record 5 of Set 8 | maarianhamina
# Processing Record 6 of Set 8 | tunduru
# Error = 'sys'
# City not found. Skipping...
# Processing Record 7 of Set 8 | hualmay
# Processing Record 8 of Set 8 | leningradskiy
# Processing Record 9 of Set 8 | kalaleh
# Processing Record 10 of Set 8 | bukama
# Processing Record 11 of Set 8 | tari
# Processing Record 12 of Set 8 | malangwa
# Processing Record 13 of Set 8 | melfi
# Processing Record 14 of Set 8 | ancud
# Processing Record 15 of Set 8 | marica
# Processing Record 16 of Set 8 | vila franca do campo
# Processing Record 17 of Set 8 | menongue
# Processing Record 18 of Set 8 | geilo
# Processing Record 19 of Set 8 | prieska
# Processing Record 20 of Set 8 | antsohihy
# Processing Record 21 of Set 8 | manono
# Processing Record 22 of Set 8 | belfast
# Processing Record 23 of Set 8 | cairns
# Processing Record 24 of Set 8 | terrace bay
# Processing Record 25 of Set 8 | maniitsoq
# Processing Record 26 of Set 8 | dalbandin
# Processing Record 27 of Set 8 | praia da vitoria
# Processing Record 28 of Set 8 | vaisala
# Error = 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 8 | singaraja
# Processing Record 30 of Set 8 | tonala
# Processing Record 31 of Set 8 | bolnisi
# Processing Record 32 of Set 8 | chengde
# Processing Record 33 of Set 8 | tabiauea
# Error = 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 8 | san cristobal
# Processing Record 35 of Set 8 | jalu
# Processing Record 36 of Set 8 | kununurra
# Processing Record 37 of Set 8 | singleton
# Processing Record 38 of Set 8 | longyearbyen
# Processing Record 39 of Set 8 | pombas
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | beyneu
# Processing Record 42 of Set 8 | urdzhar
# Error = 'sys'
# City not found. Skipping...
# Processing Record 43 of Set 8 | fernley
# Processing Record 44 of Set 8 | rio gallegos
# Processing Record 45 of Set 8 | redwater
# Processing Record 46 of Set 8 | oistins
# Processing Record 47 of Set 8 | gimli
# Processing Record 48 of Set 8 | natitingou
# Processing Record 49 of Set 8 | shache
# Processing Record 50 of Set 8 | dunshaughlin
# Processing Record 1 of Set 9 | eskasem
# Error = 'sys'
# City not found. Skipping...
# Processing Record 2 of Set 9 | barroquinha
# Processing Record 3 of Set 9 | iralaya
# Processing Record 4 of Set 9 | katete
# Processing Record 5 of Set 9 | tallahassee
# Processing Record 6 of Set 9 | plastun
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | trelew
# Processing Record 9 of Set 9 | kawalu
# Processing Record 10 of Set 9 | omsukchan
# Processing Record 11 of Set 9 | gallup
# Processing Record 12 of Set 9 | chuguyevka
# Processing Record 13 of Set 9 | gweta
# Processing Record 14 of Set 9 | erzin
# Processing Record 15 of Set 9 | aden
# Processing Record 16 of Set 9 | chimoio
# Processing Record 17 of Set 9 | chesapeake
# Processing Record 18 of Set 9 | kaeo
# Processing Record 19 of Set 9 | high level
# Processing Record 20 of Set 9 | portland
# Processing Record 21 of Set 9 | rajamahendri
# Error = 'sys'
# City not found. Skipping...
# Processing Record 22 of Set 9 | naze
# Processing Record 23 of Set 9 | ponta do sol
# Processing Record 24 of Set 9 | cherskiy
# Processing Record 25 of Set 9 | harlingen
# Processing Record 26 of Set 9 | mizan teferi
# Processing Record 27 of Set 9 | salvador
# Processing Record 28 of Set 9 | crusetu
# Processing Record 29 of Set 9 | russell
# Processing Record 30 of Set 9 | wanning
# Processing Record 31 of Set 9 | kavaratti
# Processing Record 32 of Set 9 | jacareacanga
# Processing Record 33 of Set 9 | los llanos de aridane
# Processing Record 34 of Set 9 | walvis bay
# Processing Record 35 of Set 9 | deputatskiy
# Processing Record 36 of Set 9 | ballina
# Processing Record 37 of Set 9 | corowa
# Processing Record 38 of Set 9 | bonga
# Processing Record 39 of Set 9 | fomboni
# Processing Record 40 of Set 9 | kindu
# Processing Record 41 of Set 9 | boueni
# Processing Record 42 of Set 9 | ust-bolsheretsk
# Error = 'sys'
# City not found. Skipping...
# Processing Record 43 of Set 9 | koroni
# Processing Record 44 of Set 9 | baza
# Processing Record 45 of Set 9 | mount isa
# Processing Record 46 of Set 9 | funtua
# Processing Record 47 of Set 9 | rudsar
# Processing Record 48 of Set 9 | warqla
# Error = 'sys'
# City not found. Skipping...
# Processing Record 49 of Set 9 | casino
# Processing Record 50 of Set 9 | payson
# Processing Record 1 of Set 10 | maple creek
# Processing Record 2 of Set 10 | westport
# Processing Record 3 of Set 10 | road town
# Processing Record 4 of Set 10 | farmington
# Processing Record 5 of Set 10 | funchal
# Processing Record 6 of Set 10 | mae hong son
# Processing Record 7 of Set 10 | ostersund
# Processing Record 8 of Set 10 | cayenne
# Processing Record 9 of Set 10 | dawei
# Processing Record 10 of Set 10 | atotonilco el grande
# Processing Record 11 of Set 10 | puerto quijarro
# Processing Record 12 of Set 10 | chichica
# Processing Record 13 of Set 10 | babra
# Processing Record 14 of Set 10 | si sa ket
# Processing Record 15 of Set 10 | turinskaya sloboda
# Processing Record 16 of Set 10 | taman
# Processing Record 17 of Set 10 | simplicio mendes
# Processing Record 18 of Set 10 | champerico
# Processing Record 19 of Set 10 | buala
# Processing Record 20 of Set 10 | saint anthony
# Processing Record 21 of Set 10 | macaboboni
# Error = 'sys'
# City not found. Skipping...
# Processing Record 22 of Set 10 | sobolevo
# Processing Record 23 of Set 10 | ornskoldsvik
# Processing Record 24 of Set 10 | guerrero negro
# Processing Record 25 of Set 10 | waterford
# Processing Record 26 of Set 10 | norman wells
# Processing Record 27 of Set 10 | goba
# Processing Record 28 of Set 10 | kidal
# Processing Record 29 of Set 10 | pemba
# Processing Record 30 of Set 10 | bogale
# Processing Record 31 of Set 10 | kaitangata
# Processing Record 32 of Set 10 | bouar
# Processing Record 33 of Set 10 | patiya
# Processing Record 34 of Set 10 | huarmey
# Processing Record 35 of Set 10 | camana
# Processing Record 36 of Set 10 | shimoda
# Processing Record 37 of Set 10 | socuellamos
# Processing Record 38 of Set 10 | yenagoa
# Processing Record 39 of Set 10 | kimberley
# Processing Record 40 of Set 10 | lanxi
# Processing Record 41 of Set 10 | nemuro
# Processing Record 42 of Set 10 | umm ruwabah
# Error = 'sys'
# City not found. Skipping...
# Processing Record 43 of Set 10 | shenjiamen
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | ilebo
# Processing Record 46 of Set 10 | karauzyak
# Error = 'sys'
# City not found. Skipping...
# Processing Record 47 of Set 10 | hwange
# Processing Record 48 of Set 10 | panguna
# Processing Record 49 of Set 10 | zonguldak
# Processing Record 50 of Set 10 | kyshtovka
# Processing Record 1 of Set 11 | sao filipe
# Processing Record 2 of Set 11 | aykhal
# Processing Record 3 of Set 11 | kisesa
# Processing Record 4 of Set 11 | ugoofaaru
# Processing Record 5 of Set 11 | karkaralinsk
# Error = 'sys'
# City not found. Skipping...
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | sakakah
# Processing Record 8 of Set 11 | kirya
# Processing Record 9 of Set 11 | minot
# Processing Record 10 of Set 11 | baykit
# Processing Record 11 of Set 11 | jining
# Processing Record 12 of Set 11 | billings
# Processing Record 13 of Set 11 | samarai
# Processing Record 14 of Set 11 | iwanai
# Processing Record 15 of Set 11 | broken hill
# Processing Record 16 of Set 11 | kambove
# Processing Record 17 of Set 11 | saint-louis
# Processing Record 18 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 11 | terney
# Processing Record 20 of Set 11 | nguiu
# Error = 'sys'
# City not found. Skipping...
# Processing Record 21 of Set 11 | sibolga
# Processing Record 22 of Set 11 | san policarpo
# Processing Record 23 of Set 11 | shijak
# Processing Record 24 of Set 11 | escarcega
# Processing Record 25 of Set 11 | isiolo
# Processing Record 26 of Set 11 | balykshi
# Processing Record 27 of Set 11 | saleaula
# Error = 'sys'
# City not found. Skipping...
# Processing Record 28 of Set 11 | saryagash
# Processing Record 29 of Set 11 | sataua
# Error = 'sys'
# City not found. Skipping...
# Processing Record 30 of Set 11 | kibala
# Processing Record 31 of Set 11 | bafia
# Processing Record 32 of Set 11 | zhigalovo
# Processing Record 33 of Set 11 | lunenburg
# Processing Record 34 of Set 11 | dien bien
# Error = 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 11 | owando
# Processing Record 36 of Set 11 | san jose
# Processing Record 37 of Set 11 | san patricio
# Processing Record 38 of Set 11 | tucurui
# Processing Record 39 of Set 11 | sao joao da barra
# Processing Record 40 of Set 11 | fort saint john
# Error = 'sys'
# City not found. Skipping...
# Processing Record 41 of Set 11 | sinnamary
# Processing Record 42 of Set 11 | salamanca
# Processing Record 43 of Set 11 | asfi
# Processing Record 44 of Set 11 | barroso
# Processing Record 45 of Set 11 | nadym
# Processing Record 46 of Set 11 | halalo
# Error = 'sys'
# City not found. Skipping...
# Processing Record 47 of Set 11 | kribi
# Processing Record 48 of Set 11 | camacha
# Processing Record 49 of Set 11 | utiroa
# Error = 'sys'
# City not found. Skipping...
# Processing Record 50 of Set 11 | casian
# Processing Record 1 of Set 12 | henties bay
# Processing Record 2 of Set 12 | urumqi
# Processing Record 3 of Set 12 | orito
# Processing Record 4 of Set 12 | port lincoln
# Processing Record 5 of Set 12 | yashalta
# Processing Record 6 of Set 12 | cap malheureux
# Processing Record 7 of Set 12 | nyurba
# Processing Record 8 of Set 12 | coos bay
# Processing Record 9 of Set 12 | namibe
# Processing Record 10 of Set 12 | barawe
# Error = 'sys'
# City not found. Skipping...
# Processing Record 11 of Set 12 | bargal
# Error = 'sys'
# City not found. Skipping...
# Processing Record 12 of Set 12 | nhulunbuy
# Processing Record 13 of Set 12 | gazanjyk
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | oskaloosa
# Processing Record 16 of Set 12 | kashi
# Processing Record 17 of Set 12 | andevoranto
# Error = 'sys'
# City not found. Skipping...
# Processing Record 18 of Set 12 | faya
# Processing Record 19 of Set 12 | kolondieba
# Processing Record 20 of Set 12 | kalashnikovo
# Processing Record 21 of Set 12 | barcelona
# Processing Record 22 of Set 12 | sao lourenco do sul
# Processing Record 23 of Set 12 | santa cruz
# Processing Record 24 of Set 12 | ferme-neuve
# Processing Record 25 of Set 12 | esperance
# Processing Record 26 of Set 12 | salinopolis
# Processing Record 27 of Set 12 | sistranda
# Processing Record 28 of Set 12 | qandala
# Processing Record 29 of Set 12 | vallenar
# Processing Record 30 of Set 12 | belmonte
# Processing Record 31 of Set 12 | erenhot
# Processing Record 32 of Set 12 | kikwit
# Processing Record 33 of Set 12 | udachnyy
# Processing Record 34 of Set 12 | bolungarvik
# Error = 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 12 | gravdal
# Processing Record 36 of Set 12 | bourne
# Processing Record 37 of Set 12 | esmeraldas
# Processing Record 38 of Set 12 | vagur
# Processing Record 39 of Set 12 | jiddah
# Error = 'sys'
# City not found. Skipping...
# Processing Record 40 of Set 12 | karpathos
# Processing Record 41 of Set 12 | abu samrah
# Processing Record 42 of Set 12 | santa maria
# Processing Record 43 of Set 12 | sirjan
# Processing Record 44 of Set 12 | ondorhaan
# Error = 'sys'
# City not found. Skipping...
# Processing Record 45 of Set 12 | margate
# Processing Record 46 of Set 12 | teya
# Processing Record 47 of Set 12 | sibu
# Processing Record 48 of Set 12 | stornoway
# Processing Record 49 of Set 12 | jingcheng
# Processing Record 50 of Set 12 | mergui
# Error = 'sys'
# City not found. Skipping...
# Processing Record 1 of Set 13 | yaring
# Processing Record 2 of Set 13 | kamloops
# Processing Record 3 of Set 13 | neryungri
# Processing Record 4 of Set 13 | danane
# Processing Record 5 of Set 13 | vreed en hoop
# Error = 'sys'
# City not found. Skipping...
# Processing Record 6 of Set 13 | sorong
# Processing Record 7 of Set 13 | quime
# Processing Record 8 of Set 13 | trincomalee
# Processing Record 9 of Set 13 | glasgow
# Processing Record 10 of Set 13 | vavoua
# Processing Record 11 of Set 13 | sorland
# Processing Record 12 of Set 13 | marawi
# Processing Record 13 of Set 13 | vila velha
# Processing Record 14 of Set 13 | valparaiso
# Processing Record 15 of Set 13 | nosy varika
# Processing Record 16 of Set 13 | nicolas bravo
# Processing Record 17 of Set 13 | mishelevka
# Processing Record 18 of Set 13 | tatarbunary
# Processing Record 19 of Set 13 | havelock
# Processing Record 20 of Set 13 | pangnirtung
# Processing Record 21 of Set 13 | fukue
# Processing Record 22 of Set 13 | leh
# Processing Record 23 of Set 13 | mehamn
# Processing Record 24 of Set 13 | nisia floresta
# Processing Record 25 of Set 13 | tabuk
# Processing Record 26 of Set 13 | lahad datu
# Processing Record 27 of Set 13 | tiradentes
# Processing Record 28 of Set 13 | solnechnyy
# Processing Record 29 of Set 13 | kota kinabalu
# Processing Record 30 of Set 13 | isangel
# Processing Record 31 of Set 13 | wairoa
# Processing Record 32 of Set 13 | maningrida
# Processing Record 33 of Set 13 | honiara
# Processing Record 34 of Set 13 | ilulissat
# Processing Record 35 of Set 13 | kualakapuas
# Processing Record 36 of Set 13 | teluknaga
# Processing Record 37 of Set 13 | great yarmouth
# Processing Record 38 of Set 13 | ukiah
# Processing Record 39 of Set 13 | rio cuarto
# Processing Record 40 of Set 13 | ozinki
# Processing Record 41 of Set 13 | ellensburg
# Processing Record 42 of Set 13 | okhotsk
# Processing Record 43 of Set 13 | sur
# Processing Record 44 of Set 13 | oranjestad
# Processing Record 45 of Set 13 | mixtequilla
# Error = 'sys'
# City not found. Skipping...
# Processing Record 46 of Set 13 | innisfail
# Processing Record 47 of Set 13 | gravelbourg
# Processing Record 48 of Set 13 | iskateley
# Processing Record 49 of Set 13 | sterling
# Processing Record 50 of Set 13 | bonthe
# Processing Record 1 of Set 14 | banjar
# Processing Record 2 of Set 14 | nuuk
# Processing Record 3 of Set 14 | stokmarknes
# Processing Record 4 of Set 14 | tambopata
# Processing Record 5 of Set 14 | nanakuli
# Processing Record 6 of Set 14 | barmer
# Processing Record 7 of Set 14 | eloi mendes
# Processing Record 8 of Set 14 | wanxian
# Processing Record 9 of Set 14 | padang
# Processing Record 10 of Set 14 | asau
# Processing Record 11 of Set 14 | mayumba
# Processing Record 12 of Set 14 | meulaboh
# Processing Record 13 of Set 14 | verkhnyaya inta
# Processing Record 14 of Set 14 | xiongshi
# Error = 'sys'
# City not found. Skipping...
# Processing Record 15 of Set 14 | anchorage
# Processing Record 16 of Set 14 | ust-kuyga
# Processing Record 17 of Set 14 | richards bay
# Processing Record 18 of Set 14 | novyy urengoy
# Processing Record 19 of Set 14 | daru
# Processing Record 20 of Set 14 | miraflores
# Processing Record 21 of Set 14 | roebourne
# Processing Record 22 of Set 14 | saint-joseph
# Processing Record 23 of Set 14 | bichura
# Processing Record 24 of Set 14 | katobu
# Processing Record 25 of Set 14 | grimmen
# Processing Record 26 of Set 14 | merrill
# Processing Record 27 of Set 14 | salaga
# Processing Record 28 of Set 14 | liniere
# Error = 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 14 | red bluff
# Processing Record 30 of Set 14 | tekkali
# Processing Record 31 of Set 14 | sorvag
# Error = 'sys'
# City not found. Skipping...
# Processing Record 32 of Set 14 | da nang
# Processing Record 33 of Set 14 | changji
# Processing Record 34 of Set 14 | kudahuvadhoo
# Processing Record 35 of Set 14 | eniwa
# Processing Record 36 of Set 14 | aguimes
# Processing Record 37 of Set 14 | el cobre
# Processing Record 38 of Set 14 | tonantins
# Processing Record 39 of Set 14 | inhambane
# Processing Record 40 of Set 14 | deer lake
# Processing Record 41 of Set 14 | bandarbeyla
# Processing Record 42 of Set 14 | culemborg
# Processing Record 43 of Set 14 | mantua
# Processing Record 44 of Set 14 | celestun
# Processing Record 45 of Set 14 | montego bay
# Processing Record 46 of Set 14 | mrirt
# Error = 'sys'
# City not found. Skipping...
# Processing Record 47 of Set 14 | manokwari
# Processing Record 48 of Set 14 | sabang
# Processing Record 49 of Set 14 | palmer
# Processing Record 50 of Set 14 | ambovombe
# Processing Record 1 of Set 15 | lar gerd
# Error = 'sys'
# City not found. Skipping...
# Processing Record 2 of Set 15 | soldotna
# Processing Record 3 of Set 15 | mayor pablo lagerenza
# Processing Record 4 of Set 15 | nongan
# Processing Record 5 of Set 15 | buraydah
# Processing Record 6 of Set 15 | svetlogorsk
# Processing Record 7 of Set 15 | gizo
# Processing Record 8 of Set 15 | kamaishi
# Processing Record 9 of Set 15 | dongkan
# Processing Record 10 of Set 15 | hella
# Processing Record 11 of Set 15 | loa janan
# Processing Record 12 of Set 15 | vytegra
# Processing Record 13 of Set 15 | maneadero
# Processing Record 14 of Set 15 | horodkivka
# Processing Record 15 of Set 15 | yulara
# Processing Record 16 of Set 15 | suntar
# Processing Record 17 of Set 15 | maragogi
# Processing Record 18 of Set 15 | andrelandia
# Processing Record 19 of Set 15 | chagda
# Error = 'sys'
# City not found. Skipping...
# Processing Record 20 of Set 15 | lyubeshiv
# Error = 'sys'
# City not found. Skipping...
# Processing Record 21 of Set 15 | coihaique
# Processing Record 22 of Set 15 | valle de juarez
# Processing Record 23 of Set 15 | aflu
# Error = 'sys'
# City not found. Skipping...
# Processing Record 24 of Set 15 | telixtlahuaca
# Error = 'sys'
# City not found. Skipping...
# Processing Record 25 of Set 15 | anloga
# Processing Record 26 of Set 15 | stellenbosch
# Processing Record 27 of Set 15 | ewa beach
# Processing Record 28 of Set 15 | kroderen
# Error = 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 15 | bud
# Processing Record 30 of Set 15 | miri
# Processing Record 31 of Set 15 | bonoua
# Processing Record 32 of Set 15 | mitu
# Processing Record 33 of Set 15 | maracacume
# Processing Record 34 of Set 15 | nago
# Processing Record 35 of Set 15 | burica
# Error = 'sys'
# City not found. Skipping...
# Processing Record 36 of Set 15 | pauini
# Processing Record 37 of Set 15 | puerto escondido
# Processing Record 38 of Set 15 | smila
# Processing Record 39 of Set 15 | ilo
# Processing Record 40 of Set 15 | birjand
# Processing Record 41 of Set 15 | fortuna
# Processing Record 42 of Set 15 | kapit
# Processing Record 43 of Set 15 | siilinjarvi
# Processing Record 44 of Set 15 | labutta
# Error = 'sys'
# City not found. Skipping...
# Processing Record 45 of Set 15 | contai
# Processing Record 46 of Set 15 | ciudad bolivar
# Processing Record 47 of Set 15 | winneba
# Processing Record 48 of Set 15 | hami
# Processing Record 49 of Set 15 | kisangani
# Processing Record 50 of Set 15 | yafran
# Processing Record 1 of Set 16 | lai
# Processing Record 2 of Set 16 | bowen
# Processing Record 3 of Set 16 | cape canaveral
# Processing Record 4 of Set 16 | onokhoy
# Processing Record 5 of Set 16 | chachapoyas
# Processing Record 6 of Set 16 | rocha
# Processing Record 7 of Set 16 | mount darwin
# Processing Record 8 of Set 16 | norden
# Processing Record 9 of Set 16 | jishou
# Processing Record 10 of Set 16 | camabatela
# Processing Record 11 of Set 16 | liverpool
# Processing Record 12 of Set 16 | mayskiy
# Processing Record 13 of Set 16 | makakilo city
# Processing Record 14 of Set 16 | acuitzio
# Processing Record 15 of Set 16 | even yehuda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Upernavik      GL  72.7868  -56.1549      6.58        80          54
# 1           Muros      ES  42.7762   -9.0603     55.99        88         100
# 2           Bluff      NZ -46.6000  168.3333     57.00        67           0
# 3        Cabedelo      BR  -6.9811  -34.8339     78.80        89           0
# 4          Touros      BR  -5.1989  -35.4608     78.80        83          20
# 5  Saint-Philippe      RE -21.3585   55.7679     78.80        73          20
# 6          Davila      PH  18.4726  120.5763     82.40        57          75
# 7       Myitkyina      MM  25.3833   97.4000     66.54        54           0
# 8       Jamestown      US  42.0970  -79.2353     57.20        30           1
# 9      San Felipe      VE  10.3399  -68.7425     70.20        87          95
#
#    Wind Speed Current Description
# 0        3.33       broken clouds
# 1       20.00     overcast clouds
# 2        1.99           clear sky
# 3        5.75           clear sky
# 4        4.61          few clouds
# 5       12.66          light rain
# 6        4.61       broken clouds
# 7        1.68           clear sky
# 8       13.15           clear sky
# 9        3.83     overcast clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv")
